# %% [markdown]
# # Expression Quality Control (Part 1)
# This is a template notebook for performing preliminary quality control on your organism's expression data.

# %% [markdown]
# ## Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from os import path

# %%
sns.set_style('ticks')

# %% [markdown]
# ### Inputs

# %% [markdown]
# Enter path of log-TPM, MultiQC, and metadata files here

# %%
logTPM_file = path.join('../..','data','raw','modulome','log_tpm_everything.csv') # Enter log-TPM filename here
multiqc_file = path.join('../..','data','raw','modulome','multiqc_stats_everything.tsv') # Enter MultiQC stats filename here
metadata_file = path.join('../..','data','raw','modulome','metadata_everything.csv') # Enter metadata filename here

# %% [markdown]
# ### Load expression data

# %%
DF_log_tpm = pd.read_csv(logTPM_file,index_col=0).fillna(0)
print('Number of genes:',DF_log_tpm.shape[0])
print('Number of samples:',DF_log_tpm.shape[1])
DF_log_tpm.head()
# Out:
# Number of genes: 5886
# Number of samples: 296
#              135-Dmannitol  136-Dmannitol  138-Dcellobiose  140-Dcellobiose  \
# Geneid
# XNR_RS30570       5.456942       5.932548         5.273563         5.247552
# XNR_RS00005       6.031769       6.354998         5.707565         6.120847
# XNR_RS00010       3.555950       3.055794         2.426080         2.287586
# XNR_RS00015       7.052569       7.252028         7.252156         7.308897
# XNR_RS00020       6.647861       6.692320         6.261563         6.332104
#
#              145-Glycerol  146-Glycerol  149-LAlanine  150-LAlanine  \
# Geneid
# XNR_RS30570      5.633562      5.144423      6.956123      6.619123
# XNR_RS00005      0.000000      6.356647      7.970440      7.316582
# XNR_RS00010      0.000000      0.000000      3.818268      4.241475
# XNR_RS00015      7.412816      7.290919      7.402119      7.404085
# XNR_RS00020      7.076383      6.990919      6.779826      6.447123
#
#              155-Glucose  156-Glucose  ...  DEL11actrepl3  DEL11repl1  \
# Geneid                                 ...
# XNR_RS30570     6.915530     7.009776  ...       2.211029    3.928508
# XNR_RS00005     8.335740     8.400185  ...       2.501691    5.525176
# XNR_RS00010     4.141733     4.401422  ...       2.600084    3.790738
# XNR_RS00015     7.604939     7.565636  ...       7.781654    7.322278
# XNR_RS00020     6.703674     6.999367  ...       7.082147    7.600982
#
#              DEL11repl2  DEL11repl3  J1074actrepl1  J1074actrepl2  \
# Geneid
# XNR_RS30570    4.778789    3.739590       4.902706       4.761865
# XNR_RS00005    6.072930    5.155803       6.283656       6.352132
# XNR_RS00010    4.979416    4.004295       3.302007       3.074590
# XNR_RS00015    7.495668    7.312891       7.426379       7.319022
# XNR_RS00020    7.579914    7.682685       7.067406       6.970119
#
#              J1074actrepl3  J1074repl1  J1074repl2  J1074repl3
# Geneid
# XNR_RS30570       4.645002    6.284284    6.142951    5.845819
# XNR_RS00005       6.167265    8.016699    7.647797    7.619081
# XNR_RS00010       2.917916    5.399214    5.359118    5.710532
# XNR_RS00015       7.444042    7.928760    7.762772    7.868651
# XNR_RS00020       7.049951    8.536959    8.388558    8.493526
#
# [5 rows x 296 columns]

# %% [markdown]
# ### Load QC data
# There may be some datasets that failed along the processing pipeline, so the number of samples with QC data may be higher than the number of samples with expression data.

# %%
DF_qc_stats = pd.read_csv(multiqc_file,index_col=0, sep='\t')
print('Number of samples with QC data:',DF_qc_stats.shape[0])
# Out:
# Number of samples with QC data: 296

# %%
DF_qc_stats.fillna(0,inplace=True)
DF_qc_stats.head()
# Out:
#                     Total  Assigned  Unassigned_rRNA  Unassigned_Unmapped  \
# Sample
# 135-Dmannitol    36018873   7168834          4993003             22814496
# 136-Dmannitol    18600840    542058           303688             17683334
# 138-Dcellobiose  29476631  15104998         10902474              1353257
# 140-Dcellobiose  20506777  10352937          7839234               902060
# 145-Glycerol     46519275     63722           128536             46314430
#
#                  Unassigned_Read_Type  Unassigned_Singleton  \
# Sample
# 135-Dmannitol                       0                     0
# 136-Dmannitol                       0                     0
# 138-Dcellobiose                     0                     0
# 140-Dcellobiose                     0                     0
# 145-Glycerol                        0                     0
#
#                  Unassigned_MappingQuality  Unassigned_Chimera  \
# Sample
# 135-Dmannitol                            0                   0
# 136-Dmannitol                            0                   0
# 138-Dcellobiose                          0                   0
# 140-Dcellobiose                          0                   0
# 145-Glycerol                             0                   0
#
#                  Unassigned_FragmentLength  Unassigned_Duplicate  ...  \
# Sample                                                            ...
# 135-Dmannitol                        12895                     0  ...
# 136-Dmannitol                         1137                     0  ...
# 138-Dcellobiose                      26573                     0  ...
# 140-Dcellobiose                      14292                     0  ...
# 145-Glycerol                           273                     0  ...
#
#                   r_written  bp_processed  quality_trimmed    bp_written  \
# Sample
# 135-Dmannitol    36194501.0  5.429175e+09        7059833.0  5.107978e+09
# 136-Dmannitol    18707509.0  2.806126e+09        3942355.0  2.634227e+09
# 138-Dcellobiose  29616731.0  4.442510e+09        7427181.0  4.132981e+09
# 140-Dcellobiose  20612066.0  3.091810e+09        5097553.0  2.849551e+09
# 145-Glycerol     46691271.0  7.003691e+09        8029853.0  6.599708e+09
#
#                  percent_trimmed  pe_sense  pe_antisense  failed  Unnamed: 54  \
# Sample
# 135-Dmannitol           5.916125    0.0137        0.3111  0.6752          0.0
# 136-Dmannitol           6.125851    0.0151        0.3491  0.6358          0.0
# 138-Dcellobiose         6.967427    0.0123        0.3029  0.6849          0.0
# 140-Dcellobiose         7.835495    0.0129        0.3032  0.6839          0.0
# 145-Glycerol            5.768145    0.0098        0.1832  0.8070          0.0
#
#                  Unnamed: 55
# Sample
# 135-Dmannitol            0.0
# 136-Dmannitol            0.0
# 138-Dcellobiose          0.0
# 140-Dcellobiose          0.0
# 145-Glycerol             0.0
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Load metadata

# %%
DF_metadata = pd.read_csv(metadata_file,index_col=0)
print('Number of samples with metadata:',DF_metadata.shape[0])
DF_metadata.head()
# Out:
# Number of samples with metadata: 296
#                    sample_id strain       project             condition  \
# Experiment
# L-galactose-1  L-galactose-1  J1074  azenta trial           L-galactose
# L-galactose-2  L-galactose-2  J1074  azenta trial           L-galactose
# MSG-1A                MSG-1A  J1074  azenta trial  Monosodium glutamate
# MSG-1B                MSG-1B  J1074  azenta trial  Monosodium glutamate
# MSG-2A                MSG-2A  J1074  azenta trial  Monosodium glutamate
#
#                                                            notes  run  \
# Experiment
# L-galactose-1  Samples were mistakenly labelled "L-glutamate"...  NaN
# L-galactose-2  Samples were mistakenly labelled "L-glutamate"...  NaN
# MSG-1A         sample_id: (carbon source)-(biological replica...  NaN
# MSG-1B         sample_id: (carbon source)-(biological replica...  NaN
# MSG-2A         sample_id: (carbon source)-(biological replica...  NaN
#
#               ReleaseDate      Type            sequencing_run LibraryLayout  \
# Experiment
# L-galactose-1  20/12/2023  in-house  run_01_02__merged_azenta        PAIRED
# L-galactose-2  20/12/2023  in-house  run_01_02__merged_azenta        PAIRED
# MSG-1A         20/12/2023  in-house  run_01_02__merged_azenta        PAIRED
# MSG-1B         20/12/2023  in-house  run_01_02__merged_azenta        PAIRED
# MSG-2A         20/12/2023  in-house  run_01_02__merged_azenta        PAIRED
#
#                Platform                                                 R1  \
# Experiment
# L-galactose-1  ILLUMINA  /home/nimat/reads/streptsd/ready/merged_L-glut...
# L-galactose-2  ILLUMINA  /home/nilmat/reads/streptsd/ready/merged_L-glu...
# MSG-1A         ILLUMINA  /home/nilmat/reads/streptsd/ready/merged_MSG-1...
# MSG-1B         ILLUMINA  /home/nilmat/reads/streptsd/ready/merged_MSG-1...
# MSG-2A         ILLUMINA  /home/nilmat/reads/streptsd/ready/merged_MSG-2...
#
#                                                               R2   skip  \
# Experiment
# L-galactose-1  /home/nilmat/reads/streptsd/ready/merged_L-glu...  False
# L-galactose-2  /home/nilmat/reads/streptsd/ready/merged_L-glu...  False
# MSG-1A         /home/nilmat/reads/streptsd/ready/merged_MSG-1...  False
# MSG-1B         /home/nilmat/reads/streptsd/ready/merged_MSG-1...  False
# MSG-2A         /home/nilmat/reads/streptsd/ready/merged_MSG-2...  False
#
#                 reference_condition
# Experiment
# L-galactose-1  Monosodium glutamate
# L-galactose-2  Monosodium glutamate
# MSG-1A         Monosodium glutamate
# MSG-1B         Monosodium glutamate
# MSG-2A         Monosodium glutamate

# %% [markdown]
# ### Remove extra sample rows

# %% [markdown]
# Ensure that metadata and qc_stats data contain all log_tpm sample information.

# %%
assert(set(DF_log_tpm.columns) - set(DF_metadata.index) == set())
assert(set(DF_log_tpm.columns) - set(DF_qc_stats.index) == set())

# %%
DF_metadata = DF_metadata.loc[DF_log_tpm.columns]
DF_qc_stats = DF_qc_stats.loc[DF_log_tpm.columns]

# %% [markdown]
# ## Check QC statistics

# %% [markdown]
# ### FastQC quality control

# %%
fastqc_cols = ['per_base_sequence_quality',
       'per_tile_sequence_quality', 'per_sequence_quality_scores',
       'per_base_sequence_content', 'per_sequence_gc_content',
       'per_base_n_content', 'sequence_length_distribution',
       'sequence_duplication_levels', 'overrepresented_sequences',
       'adapter_content']

# %%
DF_fastqc = DF_qc_stats[fastqc_cols]
ax = sns.heatmap(DF_fastqc.replace('pass',1).replace('warn',0).replace('fail',-1),
            cmap='RdYlBu',vmax=1.3,vmin=-1.3)
cbar = ax.collections[0].colorbar
cbar.set_ticks([-1,0,1])
cbar.set_ticklabels(['fail','warn','pass'])

# %% [markdown]
# The following four categories are the most important:
# * per_base_sequence_quality
# * per_sequence_quality_scores
# * per_base_n_content
# * adapter_content
#
# If a sample does not pass any of these four categories, discard the sample.

# %%
fastqc_fail_cols = ['per_base_sequence_quality','per_sequence_quality_scores','per_base_n_content','adapter_content']

# %%
DF_failed_fastqc = DF_fastqc[fastqc_fail_cols][(DF_fastqc[fastqc_fail_cols] != 'pass').any(axis=1)]
DF_failed_fastqc[fastqc_fail_cols]
# Out:
# Empty DataFrame
# Columns: [per_base_sequence_quality, per_sequence_quality_scores, per_base_n_content, adapter_content]
# Index: []

# %% [markdown]
# Mark samples that passed.

# %%
DF_metadata['passed_fastqc'] = ~DF_metadata.index.isin(DF_failed_fastqc.index)

# %% [markdown]
# ### Number of aligned reads

# %% [markdown]
# #### Remove potential contaminated samples based on bowtie results

# %%
DF_failed_contamination = DF_qc_stats[DF_qc_stats['reads_aligned_percentage'] < 60]
DF_failed_contamination = DF_failed_contamination.sort_values('Assigned')

# %% [markdown]
# Mark samples that passed.

# %%
DF_metadata['passed_contamination_check'] = ~DF_metadata.index.isin(DF_failed_contamination.index)

# %% [markdown]
# The following histogram shows how many reads map to coding sequences (i.e. mRNA). Too few aligned reads reduces the sensitivity of the resulting data.

# %%
min_mrna_reads = 500000 # Minimum number of reads mapped to mRNA (500,000)

# %%
fig,ax = plt.subplots()
ax.hist(DF_qc_stats['Assigned']/1e6,bins=50,alpha=0.8)
ymin,ymax = ax.get_ylim()
ax.vlines(min_mrna_reads/1e6,ymin,ymax,color='r')
ax.set_ylim((ymin,ymax))
ax.set_xlabel('# Reads (M)',fontsize=14)
ax.set_ylabel('# Samples',fontsize=14)
ax.set_title('Number of reads mapped to CDS',fontsize=16)
# Out:
# Text(0.5, 1.0, 'Number of reads mapped to CDS')

# %% [markdown]
# Identify samples with poor read depth:

# %%
DF_failed_mrna = DF_qc_stats[DF_qc_stats['Assigned'] < min_mrna_reads].sort_values('Assigned')
DF_failed_mrna
# Out:
#                  Total  Assigned  Unassigned_rRNA  Unassigned_Unmapped  \
# 188-MSG42C    19355213       130              180             19354833
# 187-MSG42C    18406569       204              523             18405725
# 450-MSGpH9    27397593      1931            28268             27366316
# 194-ISP242C   17020648      2050             6484             17011480
# 425-Proline   31508549      2447             8419             31497148
# 196-ISP242C   16714256      3777            16124             16692785
# 412-Mannose   16040852      4438             6161             16029119
# 421-Valine    19438237      5561            24540             19406559
# 407-ISP2pH8   18654904      6074            38286             18607800
# 443-MSGpH9    48995914      7160            30960             48955110
# 406-ISP2pH8   23165506      8749            35008             23118348
# 411-Mannose   22608312     10882            16751             22578068
# SRX7552680    30449944     16649           264008             30144593
# 426-Proline   24634860     18502            43545             24569287
# 424-Valine    24958662     23165            82438             24847922
# 232-ISP2pH6   44285807     41417            71671             44162374
# 231-ISP2pH6   19565436     43362            58945             19451532
# 416-Ribose    21953599     45261           105894             21789005
# SRX7552682    37266769     47366           568014             36594329
# 198-ISP2pH5   37444779     49274           134467             37242328
# SRX7552681    37846904     57008           626562             37075383
# 145-Glycerol  46519275     63722           128536             46314430
# 240-ISP27     37991105     66126            53626             37844260
# 200-ISP2pH5   26857220     75628           229879             26526480
# 239-ISP27     28026353     83480            66457             27842966
# 236-ISP25     21878471     99458           109499             21636113
# SRX7552683    37134244    105501           426895             36529277
# 201-MSGpH8    20609379    110128           637250             19829231
# 234-ISP25     22957707    174463           132774             22607225
# 146-Glycerol  33674401    180192           168439             33299252
# 202-MSGpH8    17643243    193980           799346             16594797
# ERX3196634     3734178    220510          3204050               159839
# ERX3196638     5928485    264617          5324249               142167
# ERX3196642     6947333    291919          6193512               271101
# 415-Ribose    41079017    300051           353032             40360832
# ERX3196630     6621881    476258          5783443               160905
# SRX6445017    20921630    485221          2084924             16741925
# SRX6445016    21044162    491890          2043272             16908732
#
#               Unassigned_Read_Type  Unassigned_Singleton  \
# 188-MSG42C                       0                     0
# 187-MSG42C                       0                     0
# 450-MSGpH9                       0                     0
# 194-ISP242C                      0                     0
# 425-Proline                      0                     0
# 196-ISP242C                      0                     0
# 412-Mannose                      0                     0
# 421-Valine                       0                     0
# 407-ISP2pH8                      0                     0
# 443-MSGpH9                       0                     0
# 406-ISP2pH8                      0                     0
# 411-Mannose                      0                     0
# SRX7552680                       0                     0
# 426-Proline                      0                     0
# 424-Valine                       0                     0
# 232-ISP2pH6                      0                     0
# 231-ISP2pH6                      0                     0
# 416-Ribose                       0                     0
# SRX7552682                       0                     0
# 198-ISP2pH5                      0                     0
# SRX7552681                       0                     0
# 145-Glycerol                     0                     0
# 240-ISP27                        0                     0
# 200-ISP2pH5                      0                     0
# 239-ISP27                        0                     0
# 236-ISP25                        0                     0
# SRX7552683                       0                     0
# 201-MSGpH8                       0                     0
# 234-ISP25                        0                     0
# 146-Glycerol                     0                     0
# 202-MSGpH8                       0                     0
# ERX3196634                       0                     0
# ERX3196638                       0                     0
# ERX3196642                       0                     0
# 415-Ribose                       0                     0
# ERX3196630                       0                     0
# SRX6445017                       0                     0
# SRX6445016                       0                     0
#
#               Unassigned_MappingQuality  Unassigned_Chimera  \
# 188-MSG42C                            0                   0
# 187-MSG42C                            0                   0
# 450-MSGpH9                            0                   0
# 194-ISP242C                           0                   0
# 425-Proline                           0                   0
# 196-ISP242C                           0                   0
# 412-Mannose                           0                   0
# 421-Valine                            0                   0
# 407-ISP2pH8                           0                   0
# 443-MSGpH9                            0                   0
# 406-ISP2pH8                           0                   0
# 411-Mannose                           0                   0
# SRX7552680                            0                   0
# 426-Proline                           0                   0
# 424-Valine                            0                   0
# 232-ISP2pH6                           0                   0
# 231-ISP2pH6                           0                   0
# 416-Ribose                            0                   0
# SRX7552682                            0                   0
# 198-ISP2pH5                           0                   0
# SRX7552681                            0                   0
# 145-Glycerol                          0                   0
# 240-ISP27                             0                   0
# 200-ISP2pH5                           0                   0
# 239-ISP27                             0                   0
# 236-ISP25                             0                   0
# SRX7552683                            0                   0
# 201-MSGpH8                            0                   0
# 234-ISP25                             0                   0
# 146-Glycerol                          0                   0
# 202-MSGpH8                            0                   0
# ERX3196634                            0                   0
# ERX3196638                            0                   0
# ERX3196642                            0                   0
# 415-Ribose                            0                   0
# ERX3196630                            0                   0
# SRX6445017                            0                   0
# SRX6445016                            0                   0
#
#               Unassigned_FragmentLength  Unassigned_Duplicate  ...  \
# 188-MSG42C                           11                     0  ...
# 187-MSG42C                           17                     0  ...
# 450-MSGpH9                           66                     0  ...
# 194-ISP242C                          22                     0  ...
# 425-Proline                          74                     0  ...
# 196-ISP242C                          29                     0  ...
# 412-Mannose                          36                     0  ...
# 421-Valine                           32                     0  ...
# 407-ISP2pH8                          50                     0  ...
# 443-MSGpH9                          146                     0  ...
# 406-ISP2pH8                          56                     0  ...
# 411-Mannose                         131                     0  ...
# SRX7552680                        23898                     0  ...
# 426-Proline                          92                     0  ...
# 424-Valine                          111                     0  ...
# 232-ISP2pH6                         127                     0  ...
# 231-ISP2pH6                         108                     0  ...
# 416-Ribose                          393                     0  ...
# SRX7552682                        56051                     0  ...
# 198-ISP2pH5                         191                     0  ...
# SRX7552681                        83863                     0  ...
# 145-Glycerol                        273                     0  ...
# 240-ISP27                           176                     0  ...
# 200-ISP2pH5                         277                     0  ...
# 239-ISP27                           215                     0  ...
# 236-ISP25                           270                     0  ...
# SRX7552683                        55718                     0  ...
# 201-MSGpH8                         1039                     0  ...
# 234-ISP25                           432                     0  ...
# 146-Glycerol                        418                     0  ...
# 202-MSGpH8                          889                     0  ...
# ERX3196634                         3633                     0  ...
# ERX3196638                         7060                     0  ...
# ERX3196642                         5469                     0  ...
# 415-Ribose                         1419                     0  ...
# ERX3196630                         7492                     0  ...
# SRX6445017                            0                     0  ...
# SRX6445016                            0                     0  ...
#
#                r_written  bp_processed  quality_trimmed    bp_written  \
# 188-MSG42C    19476599.0  2.921490e+09        3386129.0  2.702128e+09
# 187-MSG42C    18558236.0  2.783735e+09        3457758.0  2.533341e+09
# 450-MSGpH9    27947921.0  4.192188e+09        6049344.0  3.780675e+09
# 194-ISP242C   17146425.0  2.571964e+09        3604397.0  2.388874e+09
# 425-Proline   31951749.0  4.792762e+09        6774269.0  4.362086e+09
# 196-ISP242C   16891493.0  2.533724e+09        6334461.0  2.313870e+09
# 412-Mannose   16237281.0  2.435592e+09        2907204.0  2.226382e+09
# 421-Valine    20060114.0  3.009017e+09        4220526.0  2.782293e+09
# 407-ISP2pH8   18822896.0  2.823434e+09        3749561.0  2.632912e+09
# 443-MSGpH9    49924818.0  7.488723e+09       11234179.0  6.744322e+09
# 406-ISP2pH8   23272472.0  3.490871e+09        5227150.0  3.278264e+09
# 411-Mannose   22812278.0  3.421842e+09        2840542.0  3.200272e+09
# SRX7552680    30478705.0  4.571806e+09       14180587.0  4.379595e+09
# 426-Proline   25121979.0  3.768297e+09        6677984.0  3.380088e+09
# 424-Valine    25456007.0  3.818401e+09        3807459.0  3.568343e+09
# 232-ISP2pH6   44492982.0  6.673947e+09        9215043.0  6.243815e+09
# 231-ISP2pH6   19667618.0  2.950143e+09        4040899.0  2.711398e+09
# 416-Ribose    22017361.0  3.302604e+09        3054111.0  3.039679e+09
# SRX7552682    37328049.0  5.599207e+09       26179050.0  5.262932e+09
# 198-ISP2pH5   37640415.0  5.646062e+09        9510604.0  5.217596e+09
# SRX7552681    37902518.0  5.685378e+09       37408588.0  5.219115e+09
# 145-Glycerol  46691271.0  7.003691e+09        8029853.0  6.599708e+09
# 240-ISP27     38162908.0  5.724436e+09       10134224.0  5.317139e+09
# 200-ISP2pH5   26952216.0  4.042832e+09        6692090.0  3.762521e+09
# 239-ISP27     28185834.0  4.227875e+09        6745035.0  3.882107e+09
# 236-ISP25     22001368.0  3.300205e+09        7446905.0  3.040224e+09
# SRX7552683    37205296.0  5.580794e+09       28765263.0  5.232257e+09
# 201-MSGpH8    20697862.0  3.104679e+09        3942763.0  2.851740e+09
# 234-ISP25     23052940.0  3.457941e+09        8182690.0  3.220314e+09
# 146-Glycerol  33827445.0  5.074117e+09        6180906.0  4.795758e+09
# 202-MSGpH8    17738727.0  2.660809e+09        3330274.0  2.463520e+09
# ERX3196634     3746581.0  2.435278e+08         931309.0  2.407960e+08
# ERX3196638     5948261.0  3.866370e+08        1505872.0  3.822445e+08
# ERX3196642     6970572.0  4.530872e+08        1800427.0  4.478245e+08
# 415-Ribose    41717095.0  6.257564e+09       10571526.0  5.605571e+09
# ERX3196630     6643997.0  4.318598e+08        1711634.0  4.268759e+08
# SRX6445017    20922066.0  1.046103e+09         664965.0  1.037920e+09
# SRX6445016           0.0  0.000000e+00              0.0  0.000000e+00
#
#               percent_trimmed  pe_sense  pe_antisense  failed  Unnamed: 54  \
# 188-MSG42C           7.508557    0.0579        0.2763  0.6658       0.0000
# 187-MSG42C           8.994893    0.0344        0.1878  0.7778       0.0000
# 450-MSGpH9           9.816200    0.0048        0.0446  0.9506       0.0000
# 194-ISP242C          7.118658    0.0139        0.1335  0.8526       0.0000
# 425-Proline          8.985964    0.0081        0.1253  0.8666       0.0000
# 196-ISP242C          8.677090    0.0139        0.1155  0.8705       0.0000
# 412-Mannose          8.589692    0.0128        0.2205  0.7667       0.0000
# 421-Valine           7.534817    0.0078        0.1040  0.8882       0.0000
# 407-ISP2pH8          6.747889    0.0116        0.0842  0.9042       0.0000
# 443-MSGpH9           9.940296    0.0119        0.1174  0.8707       0.0000
# 406-ISP2pH8          6.090362    0.0144        0.1126  0.8730       0.0000
# 411-Mannose          6.475148    0.0189        0.2139  0.7671       0.0000
# SRX7552680           4.204270    0.0292        0.0472  0.9236       0.0000
# 426-Proline         10.301983    0.0084        0.1591  0.8325       0.0000
# 424-Valine           6.548773    0.0078        0.1227  0.8695       0.0000
# 232-ISP2pH6          6.444939    0.0145        0.2029  0.7826       0.0000
# 231-ISP2pH6          8.092634    0.0218        0.2302  0.7480       0.0000
# 416-Ribose           7.961135    0.0155        0.1602  0.8243       0.0000
# SRX7552682           6.005773    0.0371        0.0586  0.9043       0.0000
# 198-ISP2pH5          7.588771    0.0155        0.1409  0.8437       0.0000
# SRX7552681           8.201089    0.0428        0.0554  0.9018       0.0000
# 145-Glycerol         5.768145    0.0098        0.1832  0.8070       0.0000
# 240-ISP27            7.115059    0.0479        0.2861  0.6660       0.0000
# 200-ISP2pH5          6.933539    0.0134        0.1319  0.8547       0.0000
# 239-ISP27            8.178300    0.0484        0.2847  0.6670       0.0000
# 236-ISP25            7.877723    0.0283        0.2602  0.7115       0.0000
# SRX7552683           6.245299    0.0381        0.1406  0.8213       0.0000
# 201-MSGpH8           8.147025    0.0061        0.0870  0.9068       0.0000
# 234-ISP25            6.871912    0.0258        0.3034  0.6708       0.0000
# 146-Glycerol         5.485853    0.0138        0.2736  0.7126       0.0000
# 202-MSGpH8           7.414645    0.0075        0.1068  0.8858       0.0000
# ERX3196634           1.121755    0.0109        0.0462  0.9429       0.0000
# ERX3196638           1.136082    0.0087        0.0340  0.9573       0.0000
# ERX3196642           1.161526    0.0084        0.0318  0.9598       0.0000
# 415-Ribose          10.419286    0.0134        0.2405  0.7461       0.0000
# ERX3196630           1.154048    0.0100        0.0510  0.9390       0.0000
# SRX6445017           0.782309    0.0000        0.0000  0.4720       0.3870
# SRX6445016           0.000000    0.0000        0.0000  0.4756       0.3829
#
#               Unnamed: 55
# 188-MSG42C         0.0000
# 187-MSG42C         0.0000
# 450-MSGpH9         0.0000
# 194-ISP242C        0.0000
# 425-Proline        0.0000
# 196-ISP242C        0.0000
# 412-Mannose        0.0000
# 421-Valine         0.0000
# 407-ISP2pH8        0.0000
# 443-MSGpH9         0.0000
# 406-ISP2pH8        0.0000
# 411-Mannose        0.0000
# SRX7552680         0.0000
# 426-Proline        0.0000
# 424-Valine         0.0000
# 232-ISP2pH6        0.0000
# 231-ISP2pH6        0.0000
# 416-Ribose         0.0000
# SRX7552682         0.0000
# 198-ISP2pH5        0.0000
# SRX7552681         0.0000
# 145-Glycerol       0.0000
# 240-ISP27          0.0000
# 200-ISP2pH5        0.0000
# 239-ISP27          0.0000
# 236-ISP25          0.0000
# SRX7552683         0.0000
# 201-MSGpH8         0.0000
# 234-ISP25          0.0000
# 146-Glycerol       0.0000
# 202-MSGpH8         0.0000
# ERX3196634         0.0000
# ERX3196638         0.0000
# ERX3196642         0.0000
# 415-Ribose         0.0000
# ERX3196630         0.0000
# SRX6445017         0.1410
# SRX6445016         0.1415
#
# [38 rows x 55 columns]

# %% [markdown]
# Mark samples that passed.

# %%
DF_metadata['passed_reads_mapped_to_CDS'] = ~DF_metadata.index.isin(DF_failed_mrna.index)

# %% [markdown]
# ### Examine Global Correlations

# %% [markdown]
# Only examine data that passed the first two steps.

# %%
metadata_passed_step2 = DF_metadata[DF_metadata[['passed_fastqc','passed_reads_mapped_to_CDS', 'passed_contamination_check']].all(axis=1)]
DF_log_tpm_passed_step2 = DF_log_tpm[metadata_passed_step2.index]

# %% [markdown]
# A clustermap is a great way to visualize the global correlations between one sample and all others. The ``global_clustering`` function uses hierarchical clustering to identify specific clusters in the clustermap. The optional arguments are:
#
# * ``threshold``: Threshold used to extract clusters from the hierarchy. To increase the number of clusters, decrease the value of ``threshold``. To decrease the number of clusters, increase the value of ``threshold`` (default: 0.3)
# * ``figsize``: A tuple describing the length and width of the final clustermap. A larger figsize can make x and y-axis labels clearer.
# * ``xticklabels``: Show NCBI SRA accession numbers on the x-axis
# * ``yticklabels``: Show NCBI SRA accession numbers on the y-axis

# %%
import scipy.cluster.hierarchy as sch
import matplotlib.patches as patches

def global_clustering(data, threshold=0.3, xticklabels=False, yticklabels=False, figsize=(9,9)):
    
    # Retrieve clusters using fcluster 
    corr = data.corr()
    corr.fillna(0,inplace=True)
    dist = sch.distance.pdist(corr)
    link = sch.linkage(dist, method='complete')
    clst = pd.DataFrame(index=data.columns)
    clst['cluster'] = sch.fcluster(link, threshold * dist.max(), 'distance')

    # Get colors for each cluster
    cm = plt.cm.get_cmap('tab20')
    cluster_colors = dict(zip(clst.cluster.unique(), cm.colors))
    clst['color'] = clst.cluster.map(cluster_colors)

    print('Number of cluster: ', len(cluster_colors))
    
    legend_items = [patches.Patch(color=c, label=l) for l,c in cluster_colors.items()]
    
    sns.set(rc={'figure.facecolor':'white'})
    
    clst_map = sns.clustermap(data.corr(), 
                              figsize=figsize, 
                              row_linkage=link, 
                              col_linkage=link, 
                              col_colors=clst.color,
                              yticklabels=yticklabels, 
                              xticklabels=xticklabels,
                              vmin=0, 
                              vmax=1)
    
    legend = clst_map.ax_heatmap.legend(loc='upper left', 
                                        bbox_to_anchor=(1.01,0.85), 
                                        handles=legend_items,
                                        frameon=True)
    
    legend.set_title(title='Clusters',prop={'size':10})
    
    return clst['cluster']

# %%
clusters = global_clustering(DF_log_tpm_passed_step2)
# Out:
# Number of cluster:  18

# %% [markdown]
# Select clusters to remove.

# %%
clusters[clusters == 12]
# Out:
# 586-ISP2pH5                12
# 15-J1074-RNA-30min-ISP2    12
# 16-J1074-RNA-30min-ISP2    12
# Name: cluster, dtype: int32

# %%
remove_clusters = [0]
passed_global_corr = clusters[~clusters.isin(remove_clusters)].index

# %% [markdown]
# The following code can be adapted to see the NCBI SRA accession for samples in each cluster.

# %% [markdown]
# Re-cluster samples to ensure all outliers were removed.

# %%
DF_log_tpm_passed_step3 = DF_log_tpm[passed_global_corr]

# %%
clusters = global_clustering(DF_log_tpm_passed_step3)
# Out:
# Number of cluster:  18

# %% [markdown]
# Once you are satisfied with your dataset, mark the samples that passed the global correlation

# %%
DF_metadata['passed_global_correlation'] = DF_metadata.index.isin(passed_global_corr)

# %%
DF_metadata.head()
# Out:
#                        sample_id strain  project     condition  \
# 135-Dmannitol      135-Dmannitol  J1074  PRECISE    D-mannitol
# 136-Dmannitol      136-Dmannitol  J1074  PRECISE    D-mannitol
# 138-Dcellobiose  138-Dcellobiose  J1074  PRECISE  D-cellobiose
# 140-Dcellobiose  140-Dcellobiose  J1074  PRECISE  D-cellobiose
# 145-Glycerol        145-Glycerol  J1074  PRECISE      Glycerol
#
#                                                              notes  run  \
# 135-Dmannitol    sample_id: (carbon source)-(biological replica...  NaN
# 136-Dmannitol    sample_id: (carbon source)-(biological replica...  NaN
# 138-Dcellobiose  sample_id: (carbon source)-(biological replica...  NaN
# 140-Dcellobiose  sample_id: (carbon source)-(biological replica...  NaN
# 145-Glycerol     sample_id: (carbon source)-(biological replica...  NaN
#
#                 ReleaseDate      Type sequencing_run LibraryLayout  Platform  \
# 135-Dmannitol    20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 136-Dmannitol    20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 138-Dcellobiose  20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 140-Dcellobiose  20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 145-Glycerol     20/12/2023  in-house         run_03        PAIRED  ILLUMINA
#
#                                                                 R1  \
# 135-Dmannitol    /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 136-Dmannitol    /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 138-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 140-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 145-Glycerol     /home/nilmat/reads/streptsd/ready/azenta_run_0...
#
#                                                                 R2   skip  \
# 135-Dmannitol    /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 136-Dmannitol    /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 138-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 140-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 145-Glycerol     /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
#
#                 reference_condition  passed_fastqc  \
# 135-Dmannitol               control           True
# 136-Dmannitol               control           True
# 138-Dcellobiose             control           True
# 140-Dcellobiose             control           True
# 145-Glycerol                control           True
#
#                  passed_contamination_check  passed_reads_mapped_to_CDS  \
# 135-Dmannitol                         False                        True
# 136-Dmannitol                         False                        True
# 138-Dcellobiose                        True                        True
# 140-Dcellobiose                        True                        True
# 145-Glycerol                          False                       False
#
#                  passed_global_correlation
# 135-Dmannitol                        False
# 136-Dmannitol                        False
# 138-Dcellobiose                       True
# 140-Dcellobiose                       True
# 145-Glycerol                         False

# %% [markdown]
# # Remove failed samples

# %%
qc_columns = ['passed_fastqc',
              'passed_reads_mapped_to_CDS',
              'passed_global_correlation',
              'passed_contamination_check']

# %%
pass_qc = DF_metadata[qc_columns].all(axis=1)
DF_metadata_passed = DF_metadata[pass_qc]

# %%
_,_,pcts = plt.pie(pass_qc.value_counts().reindex([False,True]),
        labels = ['Failed','Passed'],
        colors=['tab:red','tab:blue'],
        autopct='%.0f%%',textprops={'size':16});

# Colors percents white
for pct in pcts:
    pct.set_color('white')

# %% [markdown]
# # Save current metadata

# %% [markdown]
# Enter path of interim metadata files here. It is recommended that the ``metadata_qc.tsv`` file is copied to a new ``metadata_qc_curated.tsv`` file before editing. This will prevent this notebook from over-writing any curated metadata.

# %%
metadata_all_qc_file = path.join('../..','data','interim','modulome','metadata_qc_part1_all.tsv') # Enter filename for full metadata QC file
metadata_qc_file = path.join('../..','data','interim','modulome','metadata_qc_part1.tsv') # Enter filename for metadata QC file with only passing datasets

# %%
DF_metadata.to_csv(metadata_all_qc_file, sep='\t')
DF_metadata_passed.to_csv(metadata_qc_file, sep='\t')

# %% [markdown]
# # Metadata Curation

# %% [markdown]
# The next step is to curate the metadata. At a minimum, three new columns must be added to the metadata sheet:
# * ``project``: Nickname for the project. Each bioproject should have a unique project IDs.
# * ``condition``: Nickname for the experimental condition. Biological/technical replicates must have identical condition IDs.
# * ``reference_condition``: Condition ID of the reference condition. Each project has a single reference condition (See [example metadata sheet](https://github.com/SBRG/nf-rnaseq-bacteria/blob/master/example_data/processed_data/metadata_curated.tsv))
#
# Additional columns may include:
# * ``strain_description``: The strain name, and any knock-outs or overexpressed genes
# * ``base_media``: Media used (e.g. ``M9``)
# * ``carbon_source``: Primary carbon source, with concentration in parentheses (e.g. ``glucose(.4%)``). This is usually empty for undefined media.
# * ``nitrogen_source``: Primary nitrogen source, with concentration in parentheses (e.g. ``NH4Cl(1M)``). This is usually empty for undefined media.
# * ``aerobicity``: Usually ``aerobic`` or ``anaerobic``
# * ``treatment``: Any additional supplements or treatments added to the base media (e.g. ``thiamine(0.1M)`` or ``ampicillin(100ug/mL)``)
# * ``temperature``
# * ``pH``
# * ``OD``: Approximate optical density of cells when selected for library preparation
# * ``growth_phase``: e.g. ``mid-exponential`` or ``stationary``
# * ``culture_type``: Usually ``batch`` or ``chemostat``
# * ``skip``: Whether to skip a sample due to external reasons (e.g. not traditional RNA-seq, distant strain, or lack of metadata)
#
# If specific metadata entries are not reported for a sample, these can be left blank. However, if no metadata can be gleaned from public databases, then we recommend discarding the samples.
#
# Once the metadata has been curated, proceed to [Step 2](https://github.com/avsastry/modulome-workflow/edit/main/3_quality_control/expression_QC_part2.ipynb)
