# %% [markdown]
# # Expression Quality Control (Part 2)

# %% [markdown]
# This is a template notebook for performing the final quality control on your organism's expression data. This requires a curated metadata sheet.

# %% [markdown]
# ## Setup

# %%
import itertools

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

from os import path
from scipy import stats
from tqdm.notebook import tqdm

# %%
sns.set_style('ticks')

# %% [markdown]
# ### Inputs

# %%
logTPM_file = path.join('../..','data','raw','modulome','log_tpm_everything.csv') # Enter log-TPM filename here
all_metadata_file = path.join('../..','data','interim','modulome','metadata_qc_part1_all.tsv') # Enter full metadata filename here
metadata_file = path.join('../..','data','interim','modulome','metadata_qc_part1.tsv') # Enter curated metadata filename here

# %% [markdown]
# ### Load expression data

# %%
DF_log_tpm = pd.read_csv(logTPM_file,index_col=0).fillna(0)
print('Number of genes:',DF_log_tpm.shape[0])
print('Number of samples:',DF_log_tpm.shape[1])
DF_log_tpm.head()
# Out:
# Number of genes: 5886
# Number of samples: 296
#              135-Dmannitol  136-Dmannitol  138-Dcellobiose  140-Dcellobiose  \
# Geneid
# XNR_RS30570       5.456942       5.932548         5.273563         5.247552
# XNR_RS00005       6.031769       6.354998         5.707565         6.120847
# XNR_RS00010       3.555950       3.055794         2.426080         2.287586
# XNR_RS00015       7.052569       7.252028         7.252156         7.308897
# XNR_RS00020       6.647861       6.692320         6.261563         6.332104
#
#              145-Glycerol  146-Glycerol  149-LAlanine  150-LAlanine  \
# Geneid
# XNR_RS30570      5.633562      5.144423      6.956123      6.619123
# XNR_RS00005      0.000000      6.356647      7.970440      7.316582
# XNR_RS00010      0.000000      0.000000      3.818268      4.241475
# XNR_RS00015      7.412816      7.290919      7.402119      7.404085
# XNR_RS00020      7.076383      6.990919      6.779826      6.447123
#
#              155-Glucose  156-Glucose  ...  DEL11actrepl3  DEL11repl1  \
# Geneid                                 ...
# XNR_RS30570     6.915530     7.009776  ...       2.211029    3.928508
# XNR_RS00005     8.335740     8.400185  ...       2.501691    5.525176
# XNR_RS00010     4.141733     4.401422  ...       2.600084    3.790738
# XNR_RS00015     7.604939     7.565636  ...       7.781654    7.322278
# XNR_RS00020     6.703674     6.999367  ...       7.082147    7.600982
#
#              DEL11repl2  DEL11repl3  J1074actrepl1  J1074actrepl2  \
# Geneid
# XNR_RS30570    4.778789    3.739590       4.902706       4.761865
# XNR_RS00005    6.072930    5.155803       6.283656       6.352132
# XNR_RS00010    4.979416    4.004295       3.302007       3.074590
# XNR_RS00015    7.495668    7.312891       7.426379       7.319022
# XNR_RS00020    7.579914    7.682685       7.067406       6.970119
#
#              J1074actrepl3  J1074repl1  J1074repl2  J1074repl3
# Geneid
# XNR_RS30570       4.645002    6.284284    6.142951    5.845819
# XNR_RS00005       6.167265    8.016699    7.647797    7.619081
# XNR_RS00010       2.917916    5.399214    5.359118    5.710532
# XNR_RS00015       7.444042    7.928760    7.762772    7.868651
# XNR_RS00020       7.049951    8.536959    8.388558    8.493526
#
# [5 rows x 296 columns]

# %% [markdown]
# ### Load metadata

# %%
DF_metadata = pd.read_csv(metadata_file,index_col=0, sep='\t')
print('Number of samples with curated metadata:',DF_metadata.shape[0])
DF_metadata.head()
# Out:
# Number of samples with curated metadata: 241
#                        sample_id strain  project     condition  \
# 138-Dcellobiose  138-Dcellobiose  J1074  PRECISE  D-cellobiose
# 140-Dcellobiose  140-Dcellobiose  J1074  PRECISE  D-cellobiose
# 149-LAlanine        149-LAlanine  J1074  PRECISE     L-Alanine
# 150-LAlanine        150-LAlanine  J1074  PRECISE     L-Alanine
# 155-Glucose          155-Glucose  J1074  PRECISE       Glucose
#
#                                                              notes  run  \
# 138-Dcellobiose  sample_id: (carbon source)-(biological replica...  NaN
# 140-Dcellobiose  sample_id: (carbon source)-(biological replica...  NaN
# 149-LAlanine     sample_id: (carbon source)-(biological replica...  NaN
# 150-LAlanine     sample_id: (carbon source)-(biological replica...  NaN
# 155-Glucose      sample_id: (carbon source)-(biological replica...  NaN
#
#                 ReleaseDate      Type sequencing_run LibraryLayout  Platform  \
# 138-Dcellobiose  20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 140-Dcellobiose  20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 149-LAlanine     20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 150-LAlanine     20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 155-Glucose      20/12/2023  in-house         run_03        PAIRED  ILLUMINA
#
#                                                                 R1  \
# 138-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 140-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 149-LAlanine     /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 150-LAlanine     /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 155-Glucose      /home/nilmat/reads/streptsd/ready/azenta_run_0...
#
#                                                                 R2   skip  \
# 138-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 140-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 149-LAlanine     /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 150-LAlanine     /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 155-Glucose      /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
#
#                 reference_condition  passed_fastqc  \
# 138-Dcellobiose             control           True
# 140-Dcellobiose             control           True
# 149-LAlanine                control           True
# 150-LAlanine                control           True
# 155-Glucose                 control           True
#
#                  passed_contamination_check  passed_reads_mapped_to_CDS  \
# 138-Dcellobiose                        True                        True
# 140-Dcellobiose                        True                        True
# 149-LAlanine                           True                        True
# 150-LAlanine                           True                        True
# 155-Glucose                            True                        True
#
#                  passed_global_correlation
# 138-Dcellobiose                       True
# 140-Dcellobiose                       True
# 149-LAlanine                          True
# 150-LAlanine                          True
# 155-Glucose                           True

# %%
DF_metadata_all = pd.read_csv(all_metadata_file,index_col=0, sep='\t')

# %% [markdown]
# ## Remove samples due to poor metadata

# %% [markdown]
# After curation, some samples either did not have enough replicates or metadata to warrant inclusion in this database.

# %%
DF_metadata_passed_step4 = DF_metadata[~DF_metadata.skip.fillna(False)].copy()
print('New number of samples with curated metadata:',DF_metadata_passed_step4.shape[0])
DF_metadata_passed_step4.head()
# Out:
# New number of samples with curated metadata: 241
#                        sample_id strain  project     condition  \
# 138-Dcellobiose  138-Dcellobiose  J1074  PRECISE  D-cellobiose
# 140-Dcellobiose  140-Dcellobiose  J1074  PRECISE  D-cellobiose
# 149-LAlanine        149-LAlanine  J1074  PRECISE     L-Alanine
# 150-LAlanine        150-LAlanine  J1074  PRECISE     L-Alanine
# 155-Glucose          155-Glucose  J1074  PRECISE       Glucose
#
#                                                              notes  run  \
# 138-Dcellobiose  sample_id: (carbon source)-(biological replica...  NaN
# 140-Dcellobiose  sample_id: (carbon source)-(biological replica...  NaN
# 149-LAlanine     sample_id: (carbon source)-(biological replica...  NaN
# 150-LAlanine     sample_id: (carbon source)-(biological replica...  NaN
# 155-Glucose      sample_id: (carbon source)-(biological replica...  NaN
#
#                 ReleaseDate      Type sequencing_run LibraryLayout  Platform  \
# 138-Dcellobiose  20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 140-Dcellobiose  20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 149-LAlanine     20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 150-LAlanine     20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 155-Glucose      20/12/2023  in-house         run_03        PAIRED  ILLUMINA
#
#                                                                 R1  \
# 138-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 140-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 149-LAlanine     /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 150-LAlanine     /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 155-Glucose      /home/nilmat/reads/streptsd/ready/azenta_run_0...
#
#                                                                 R2   skip  \
# 138-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 140-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 149-LAlanine     /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 150-LAlanine     /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 155-Glucose      /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
#
#                 reference_condition  passed_fastqc  \
# 138-Dcellobiose             control           True
# 140-Dcellobiose             control           True
# 149-LAlanine                control           True
# 150-LAlanine                control           True
# 155-Glucose                 control           True
#
#                  passed_contamination_check  passed_reads_mapped_to_CDS  \
# 138-Dcellobiose                        True                        True
# 140-Dcellobiose                        True                        True
# 149-LAlanine                           True                        True
# 150-LAlanine                           True                        True
# 155-Glucose                            True                        True
#
#                  passed_global_correlation
# 138-Dcellobiose                       True
# 140-Dcellobiose                       True
# 149-LAlanine                          True
# 150-LAlanine                          True
# 155-Glucose                           True

# %% [markdown]
# ### Check curation
# Since manual curation is error-prone, we want to make sure that all samples have labels for their project and condition. In addition, there should only be one reference condition in each project, and it should be in the project itself.
#
# Any samples that fail these checks will be printed below.

# %%
assert(DF_metadata_passed_step4.project.notnull().all())
assert(DF_metadata_passed_step4.condition.notnull().all())

for name,group in DF_metadata_passed_step4.groupby('project'):
    ref_cond = group.reference_condition.unique()
    
    # Ensure that there is only one reference condition per project
    if not len(ref_cond) == 1:
        print('Multiple reference conditions for:', name)
    
    # Ensure the reference condition is in fact in the project
    ref_cond = ref_cond[0]
    if not ref_cond in group.condition.tolist():
        print('Reference condition not in project:', name)

# %% [markdown]
# Next, make a new column called ``full_name`` that gives every experimental condition a unique, human-readable identifier.

# %%
DF_metadata_passed_step4['full_name'] = DF_metadata_passed_step4['project'].str.cat(DF_metadata_passed_step4['condition'],sep=':')

# %% [markdown]
# ### Remove samples with only one replicate

# %% [markdown]
# First, find sample names that have at least two replicates.

# %%
counts = DF_metadata_passed_step4.full_name.value_counts()
keep_samples = counts[counts >= 2].index
print(keep_samples[:5])
# Out:
# Index(['PRECISE:Plate-filter-2A', 'azenta trial:Monosodium glutamate',
#        'PRJNA1003853:PkasOP::zwf2_12h', 'PRJNA1003853:PkasOP::zwf2_70h',
#        'PRJNA708335:gp_5h_L_valanine'],
#       dtype='object')

# %% [markdown]
# Only keep these samples

# %%
DF_metadata_passed_step4 = DF_metadata_passed_step4[DF_metadata_passed_step4.full_name.isin(keep_samples)]
print('New number of samples with curated metadata:',DF_metadata_passed_step4.shape[0])
DF_metadata_passed_step4.head()
# Out:
# New number of samples with curated metadata: 226
#                        sample_id strain  project     condition  \
# 138-Dcellobiose  138-Dcellobiose  J1074  PRECISE  D-cellobiose
# 140-Dcellobiose  140-Dcellobiose  J1074  PRECISE  D-cellobiose
# 149-LAlanine        149-LAlanine  J1074  PRECISE     L-Alanine
# 150-LAlanine        150-LAlanine  J1074  PRECISE     L-Alanine
# 155-Glucose          155-Glucose  J1074  PRECISE       Glucose
#
#                                                              notes  run  \
# 138-Dcellobiose  sample_id: (carbon source)-(biological replica...  NaN
# 140-Dcellobiose  sample_id: (carbon source)-(biological replica...  NaN
# 149-LAlanine     sample_id: (carbon source)-(biological replica...  NaN
# 150-LAlanine     sample_id: (carbon source)-(biological replica...  NaN
# 155-Glucose      sample_id: (carbon source)-(biological replica...  NaN
#
#                 ReleaseDate      Type sequencing_run LibraryLayout  Platform  \
# 138-Dcellobiose  20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 140-Dcellobiose  20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 149-LAlanine     20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 150-LAlanine     20/12/2023  in-house         run_03        PAIRED  ILLUMINA
# 155-Glucose      20/12/2023  in-house         run_03        PAIRED  ILLUMINA
#
#                                                                 R1  \
# 138-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 140-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 149-LAlanine     /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 150-LAlanine     /home/nilmat/reads/streptsd/ready/azenta_run_0...
# 155-Glucose      /home/nilmat/reads/streptsd/ready/azenta_run_0...
#
#                                                                 R2   skip  \
# 138-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 140-Dcellobiose  /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 149-LAlanine     /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 150-LAlanine     /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
# 155-Glucose      /home/nilmat/reads/streptsd/ready/azenta_run_0...  False
#
#                 reference_condition  passed_fastqc  \
# 138-Dcellobiose             control           True
# 140-Dcellobiose             control           True
# 149-LAlanine                control           True
# 150-LAlanine                control           True
# 155-Glucose                 control           True
#
#                  passed_contamination_check  passed_reads_mapped_to_CDS  \
# 138-Dcellobiose                        True                        True
# 140-Dcellobiose                        True                        True
# 149-LAlanine                           True                        True
# 150-LAlanine                           True                        True
# 155-Glucose                            True                        True
#
#                  passed_global_correlation             full_name
# 138-Dcellobiose                       True  PRECISE:D-cellobiose
# 140-Dcellobiose                       True  PRECISE:D-cellobiose
# 149-LAlanine                          True     PRECISE:L-Alanine
# 150-LAlanine                          True     PRECISE:L-Alanine
# 155-Glucose                           True       PRECISE:Glucose

# %% [markdown]
# ### Save this information to the full metadata dataframe

# %%
DF_metadata_all['passed_curation'] = DF_metadata_all.index.isin(DF_metadata_passed_step4.index)

# %% [markdown]
# ## Check correlations between replicates

# %% [markdown]
# ### Remove failed data from log_tpm files

# %%
DF_log_tpm = DF_log_tpm[DF_metadata_passed_step4.index]

# %% [markdown]
# ### Compute Pearson R Score

# %% [markdown]
# There is precident for using 0.80 as Rcutoff value. This allows us to include all of the ERX samples in the study. Hoever, need to think carefully wether or not to include them, think about their replications (2 replicates but sampled a day apart). Additionally, plotting the samples on a PCA indicates that samples from 'K88E_mutation_in_rpsL_gene' and 'K88E_p91S_mutation_in_rpsL_gene_+del_rsmG' may have been mixed up.

# %%
rcutoff = 0.90

# %% [markdown]
# The following code computes correlations between all samples and collects correlations between replicates and non-replicates.

# %%
rep_corrs = {}
rand_corrs = {}

num_comparisons = len(DF_metadata_passed_step4)*(len(DF_metadata_passed_step4)-1)/2

for exp1,exp2 in tqdm(itertools.combinations(DF_metadata_passed_step4.index,2),total=num_comparisons):
    if DF_metadata_passed_step4.loc[exp1,'full_name'] == DF_metadata_passed_step4.loc[exp2,'full_name']:
        rep_corrs[(exp1,exp2)] = stats.pearsonr(DF_log_tpm[exp1],DF_log_tpm[exp2])[0]
    else:
        rand_corrs[(exp1,exp2)] = stats.pearsonr(DF_log_tpm[exp1],DF_log_tpm[exp2])[0]
# Out:
#   0%|          | 0/25425.0 [00:00<?, ?it/s]

# %% [markdown]
# Correlations can be plotted on a histogram

# %%
fig,ax = plt.subplots(figsize=(5,5))
ax2 = ax.twinx()
ax2.hist(rep_corrs.values(),bins=50,range=(0.2,1),alpha=0.8,color='green',linewidth=0)
ax.hist(rand_corrs.values(),bins=50,range=(0.2,1),alpha=0.8,color='blue',linewidth=0)
ax.set_title('Pearson R correlation between experiments',fontsize=14)
ax.set_xlabel('Pearson R correlation',fontsize=14)
ax.set_ylabel('Different Conditions',fontsize=14)
ax2.set_ylabel('Known Replicates',fontsize=14)

med_corr = np.median([v for k,v in rep_corrs.items()])
print('Median Pearson R between replicates: {:.2f}'.format(med_corr))

# save the plot
plt.savefig('../../reports/figures/modulome/Fig1/pearson_correlation_between_experiments.svg', dpi=300)
# Out:
# Median Pearson R between replicates: 0.99

# %% [markdown]
# Remove samples without any high-correlation replicates

# %%
dissimilar = []
for idx, grp in DF_metadata_passed_step4.groupby('full_name'):
    ident = np.identity(len(grp))
    corrs = (DF_log_tpm[grp.index].corr() - ident).max()
    dissimilar.extend(corrs[corrs<rcutoff].index)

# Save this information in both the original metadata dataframe and the new metadata dataframe
DF_metadata_all['passed_replicate_correlations'] = ~DF_metadata_all.index.isin(dissimilar)
DF_metadata_passed_step4['passed_replicate_correlations'] = ~DF_metadata_passed_step4.index.isin(dissimilar)

# %%
DF_metadata_final = DF_metadata_passed_step4[DF_metadata_passed_step4['passed_replicate_correlations']]
print('# Samples that passed replicate correlations:',len(DF_metadata_final))
# Out:
# # Samples that passed replicate correlations: 218

# %% [markdown]
# ## Check that reference conditions still exist
# If a reference condition was removed due to poor replicate correlations, a new reference condition needs to be defined.
#
# Again, any samples that fail these checks will be printed below.

# %%
project_exprs = []
for name,group in DF_metadata_final.groupby('project'):
    
    # Get reference condition
    ref_cond = group.reference_condition.iloc[0]
    
    # Ensure the reference condition is still in the project
    if ref_cond not in group.condition.tolist():
        print('Reference condition missing from:', name)
    
    # Check that each project has at least two conditions (a reference and at least one test condition)
    if len(group.condition.unique()) <= 1:
        print('Only one condition in:', name)

# %% [markdown]
# If necessary, choose a new condition for failed projects and re-run notebook.

# %% [markdown]
# ## Normalize dataset to reference conditions

# %%
DF_log_tpm_final = DF_log_tpm[DF_metadata_final.index]

# %%
project_exprs = []
for name,group in DF_metadata_final.groupby('project'):
    
    # Get reference condition
    ref_cond = group.reference_condition.iloc[0]
    
    # Get reference condition sample ids
    ref_samples = group[group.condition == ref_cond].index
    
    # Get reference condition expression
    ref_expr = DF_log_tpm_final[ref_samples].mean(axis=1)
    
    # Subtract reference expression from project
    project_exprs.append(DF_log_tpm_final[group.index].sub(ref_expr,axis=0))

DF_log_tpm_norm = pd.concat(project_exprs,axis=1)

# %% [markdown]
# ## Save final datasets

# %%
logTPM_qc_file = path.join('../..','data','processed','modulome','log_tpm.csv')
logTPM_norm_file = path.join('../..','data','processed','modulome','log_tpm_norm.csv')
final_metadata_file = path.join('../..','data','processed','modulome','metadata.tsv')
final_metadata_all_file = path.join('../..','data','interim','modulome','metadata_qc_part2_all.tsv')

DF_log_tpm_final.to_csv(logTPM_qc_file)
DF_log_tpm_norm.to_csv(logTPM_norm_file)
DF_metadata_final.to_csv(final_metadata_file, sep='\t')
DF_metadata_all.to_csv(final_metadata_all_file, sep='\t')

# %% [markdown]
# Double-check the processed files, remove any sample that has >60% unassigned reads due to 'Unmapped' these might be contaminated.
