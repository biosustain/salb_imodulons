# %%
from Bio import SeqIO
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from os import path
from pymodulon.io import *
from pymodulon.plotting import *
import os

# %% [markdown]
# ---
# According to the web search results, not all of the biosynthetic gene clusters in streptomyces are antibiotics. Some of them are involved in the production of other types of natural products, such as pigments, terpenes, siderophores, and osmolytes. Here is a list of the biosynthetic gene clusters that are known or predicted to produce antibiotics, along with their corresponding compounds and references:
#
# - **SGR PTMs**: This gene cluster is responsible for the biosynthesis of **SGR PTMs**, a group of post-translationally modified peptides with antibacterial activity against Gram-positive bacteria¹.
# - **Paulomycin**: This gene cluster encodes the enzymes and regulators for the synthesis of **paulomycin**, a glycosylated polyene macrolide with antifungal and antitumor properties².
# - **Cyclofaulknamycin**: This gene cluster is involved in the formation of **cyclofaulknamycin**, a cyclic peptide with antibacterial activity against methicillin-resistant Staphylococcus aureus (MRSA)³.
# - **synechobactin**: This gene cluster directs the production of **synechobactin**, a siderophore with antimicrobial activity against Gram-negative bacteria⁴.
# - **fluostatins**: This gene cluster is responsible for the biosynthesis of **fluostatins**, a family of polyketides with antifungal and cytotoxic activities⁵.
# - **goadsporin**: This gene cluster encodes the enzymes and regulators for the synthesis of **goadsporin**, a linear heptapeptide with antibacterial activity against Gram-positive bacteria⁶.
# - **SAL-2242**: This gene cluster is involved in the formation of **SAL-2242**, a cyclic lipopeptide with antibacterial activity against Gram-positive bacteria⁷.
# - **WS9326**: This gene cluster directs the production of **WS9326**, a cyclic peptide with antibacterial activity against Gram-positive bacteria.
# - **surugamide**: This gene cluster is responsible for the biosynthesis of **surugamide**, a cyclic lipopeptide with antibacterial activity against Gram-positive bacteria.
# - **dudomycin A**: This gene cluster encodes the enzymes and regulators for the synthesis of **dudomycin A**, a glycosylated anthracycline with antitumor activity.
# - **desferrioxamin B**: This gene cluster is involved in the formation of **desferrioxamin B**, a siderophore with antibacterial activity against Gram-negative bacteria.
# - **minimycin**: This gene cluster directs the production of **minimycin**, a glycopeptide with antibacterial activity against Gram-positive bacteria.
# - **streptamidine**: This gene cluster is responsible for the biosynthesis of **streptamidine**, an aminoglycoside with antibacterial activity against Gram-negative bacteria.
# - **candicidin**: This gene cluster encodes the enzymes and regulators for the synthesis of **candicidin**, a polyene macrolide with antifungal activity.
# - **antimycin**: This gene cluster is involved in the formation of **antimycin**, a depsipeptide with antifungal and antitumor activities.
#
# The other biosynthetic gene clusters in streptomyces are not antibiotics, but they may have other biological functions or applications. For example:
#
# - **hopene**: This gene cluster is responsible for the biosynthesis of **hopene**, a pentacyclic triterpene that serves as a membrane lipid and a precursor for hopanoids.
# - **hexacosalactone A**: This gene cluster encodes the enzymes and regulators for the synthesis of **hexacosalactone A**, a butyrolactone that acts as an autoregulator for secondary metabolism in streptomyces.
# - **geosmin**: This gene cluster is involved in the formation of **geosmin**, a sesquiterpene that gives streptomyces their characteristic earthy odor and flavor.
# - **julichrome**: This gene cluster directs the production of **julichrome**, a siderophore that binds iron and enhances growth and sporulation in streptomyces.
# - **ectoine**: This gene cluster is responsible for the biosynthesis of **ectoine**, an osmolyte that protects streptomyces from salt stress and dehydration.
# - **isorenieratene**: This gene cluster encodes the enzymes and regulators for the synthesis of **isorenieratene**, a carotenoid that gives streptomyces their yellow-orange color and protects them from oxidative damage.
# - **valinomycin**: This gene cluster is involved in the formation of **valinomycin**, a cyclic depsipeptide that acts as a potassium ionophore and disrupts the membrane potential of cells.
# ---

# %%
data_dir = data_dir = path.join('../..','data','processed')
ica_data = load_json_model(path.join(data_dir,'salb.json.gz'))

# %%
# Read the CSV file containing the imodulon names
imodulon_names_df = pd.read_csv(path.join(data_dir, 'imodulon_table.csv'))
# Extract the names into a list
imodulon_names = imodulon_names_df['Unnamed: 0'].tolist()
all_genes = []  # List to store all genes from each imodulon

for imodulon_name in imodulon_names:
    imodulome_data = ica_data.view_imodulon(imodulon_name)
    genes = imodulome_data.index.tolist()
    for gene in genes:
        all_genes.append((gene, imodulon_name))

# Convert the collected gene data to a pandas DataFrame
df = pd.DataFrame(all_genes, columns=['Gene', 'Imodulon'])

# Save the DataFrame to a CSV file
df.to_csv(path.join(data_dir,'genes_with_imodulon.csv'), index=False)

# %%
# path of gene_cluster_files
gene_cluster_files = ["../../data/external/S_albus_antismash/NC_020990.1.region001.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region002.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region003.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region004.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region005.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region006.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region007.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region008.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region009.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region010.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region011.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region012.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region013.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region014.gbk","/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region015.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region016.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region017.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region018.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region019.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region020.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region021.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region022.gbk", "/Users/nilmat/Documents/Streptomyces_main/BiGMeC_salb/S_albus_antismash/NC_020990.1.region023.gbk"] 

# List to store gene information
genes_list = []

# Iterate over each gene cluster file
for gene_cluster_file in gene_cluster_files:
    with open(gene_cluster_file, "r") as file:
        # Parse the gene cluster file
        record = SeqIO.read(file, "genbank")

        # Iterate over each gene in the gene cluster file
        for feature in record.features:
            if feature.type == "CDS":
                # Extract the gene information
                gene = {"locus_tag": feature.qualifiers["locus_tag"][0]}

                # Append the gene information to the genes_list
                genes_list.append(gene)
        


# Print the extracted gene information
for gene in genes_list:
    print(gene) 

# Write the extracted gene information to a file
with open("gene_list.txt", "w") as file:
    for gene in genes_list:
        file.write(str(gene) + "\n")
# Out:
# {'locus_tag': 'XNR_RS00010'}
# {'locus_tag': 'XNR_RS00015'}
# {'locus_tag': 'XNR_RS00020'}
# {'locus_tag': 'XNR_RS00025'}
# {'locus_tag': 'XNR_RS00030'}
# {'locus_tag': 'XNR_RS00035'}
# {'locus_tag': 'XNR_RS00040'}
# {'locus_tag': 'XNR_RS00045'}
# {'locus_tag': 'XNR_RS00050'}
# {'locus_tag': 'XNR_RS00055'}
# {'locus_tag': 'XNR_RS00060'}
# {'locus_tag': 'XNR_RS00065'}
# {'locus_tag': 'XNR_RS00070'}
# {'locus_tag': 'XNR_RS00075'}
# {'locus_tag': 'XNR_RS00080'}
# {'locus_tag': 'XNR_RS00085'}
# {'locus_tag': 'XNR_RS00090'}
# {'locus_tag': 'XNR_RS31480'}
# {'locus_tag': 'XNR_RS00100'}
# {'locus_tag': 'XNR_RS31485'}
# {'locus_tag': 'XNR_RS00110'}
# {'locus_tag': 'XNR_RS31490'}
# {'locus_tag': 'XNR_RS00115'}
# {'locus_tag': 'XNR_RS00120'}
# {'locus_tag': 'XNR_RS00125'}
# {'locus_tag': 'XNR_RS00130'}
# {'locus_tag': 'XNR_RS00135'}
# {'locus_tag': 'XNR_RS00140'}
# {'locus_tag': 'XNR_RS00145'}
# {'locus_tag': 'XNR_RS00150'}
# {'locus_tag': 'XNR_RS00155'}
# {'locus_tag': 'XNR_RS00160'}
# {'locus_tag': 'XNR_RS30400'}
# {'locus_tag': 'XNR_RS00165'}
# {'locus_tag': 'XNR_RS00170'}
# {'locus_tag': 'XNR_RS00175'}
# {'locus_tag': 'XNR_RS00180'}
# {'locus_tag': 'XNR_RS31495'}
# {'locus_tag': 'XNR_RS00185'}
# {'locus_tag': 'XNR_RS00190'}
# {'locus_tag': 'XNR_RS00195'}
# {'locus_tag': 'XNR_RS00200'}
# {'locus_tag': 'XNR_RS00205'}
# {'locus_tag': 'XNR_RS00210'}
# {'locus_tag': 'XNR_RS00920'}
# {'locus_tag': 'XNR_RS00925'}
# {'locus_tag': 'XNR_RS00930'}
# {'locus_tag': 'XNR_RS00935'}
# {'locus_tag': 'XNR_RS00940'}
# {'locus_tag': 'XNR_RS31500'}
# {'locus_tag': 'XNR_RS00950'}
# {'locus_tag': 'XNR_RS00955'}
# {'locus_tag': 'XNR_RS00960'}
# {'locus_tag': 'XNR_RS00965'}
# {'locus_tag': 'XNR_RS00970'}
# {'locus_tag': 'XNR_RS00975'}
# {'locus_tag': 'XNR_RS00980'}
# {'locus_tag': 'XNR_RS00985'}
# {'locus_tag': 'XNR_RS00990'}
# {'locus_tag': 'XNR_RS00995'}
# {'locus_tag': 'XNR_RS01000'}
# {'locus_tag': 'XNR_RS01005'}
# {'locus_tag': 'XNR_RS01010'}
# {'locus_tag': 'XNR_RS01015'}
# {'locus_tag': 'XNR_RS01020'}
# {'locus_tag': 'XNR_RS01025'}
# {'locus_tag': 'XNR_RS01035'}
# {'locus_tag': 'XNR_RS01040'}
# {'locus_tag': 'XNR_RS01045'}
# {'locus_tag': 'XNR_RS01050'}
# {'locus_tag': 'XNR_RS01055'}
# {'locus_tag': 'XNR_RS01060'}
# {'locus_tag': 'XNR_RS01065'}
# {'locus_tag': 'XNR_RS01255'}
# {'locus_tag': 'XNR_RS01260'}
# {'locus_tag': 'XNR_RS31020'}
# {'locus_tag': 'XNR_RS01270'}
# {'locus_tag': 'XNR_RS01275'}
# {'locus_tag': 'XNR_RS01280'}
# {'locus_tag': 'XNR_RS29515'}
# {'locus_tag': 'XNR_RS01290'}
# {'locus_tag': 'XNR_RS01295'}
# {'locus_tag': 'XNR_RS01300'}
# {'locus_tag': 'XNR_RS01305'}
# {'locus_tag': 'XNR_RS01310'}
# {'locus_tag': 'XNR_RS01315'}
# {'locus_tag': 'XNR_RS01320'}
# {'locus_tag': 'XNR_RS01325'}
# {'locus_tag': 'XNR_RS01330'}
# {'locus_tag': 'XNR_RS01335'}
# {'locus_tag': 'XNR_RS01340'}
# {'locus_tag': 'XNR_RS01345'}
# {'locus_tag': 'XNR_RS01350'}
# {'locus_tag': 'XNR_RS01355'}
# {'locus_tag': 'XNR_RS01360'}
# {'locus_tag': 'XNR_RS01365'}
# {'locus_tag': 'XNR_RS01370'}
# {'locus_tag': 'XNR_RS01375'}
# {'locus_tag': 'XNR_RS01695'}
# {'locus_tag': 'XNR_RS01700'}
# {'locus_tag': 'XNR_RS01705'}
# {'locus_tag': 'XNR_RS01710'}
# {'locus_tag': 'XNR_RS01715'}
# {'locus_tag': 'XNR_RS01720'}
# {'locus_tag': 'XNR_RS02805'}
# {'locus_tag': 'XNR_RS02810'}
# {'locus_tag': 'XNR_RS02815'}
# {'locus_tag': 'XNR_RS02820'}
# {'locus_tag': 'XNR_RS02825'}
# {'locus_tag': 'XNR_RS02830'}
# {'locus_tag': 'XNR_RS02835'}
# {'locus_tag': 'XNR_RS30670'}
# {'locus_tag': 'XNR_RS02840'}
# {'locus_tag': 'XNR_RS02845'}
# {'locus_tag': 'XNR_RS02850'}
# {'locus_tag': 'XNR_RS02855'}
# {'locus_tag': 'XNR_RS02860'}
# {'locus_tag': 'XNR_RS02865'}
# {'locus_tag': 'XNR_RS02870'}
# {'locus_tag': 'XNR_RS02875'}
# {'locus_tag': 'XNR_RS02880'}
# {'locus_tag': 'XNR_RS02885'}
# {'locus_tag': 'XNR_RS02890'}
# {'locus_tag': 'XNR_RS02895'}
# {'locus_tag': 'XNR_RS02900'}
# {'locus_tag': 'XNR_RS02905'}
# {'locus_tag': 'XNR_RS02910'}
# {'locus_tag': 'XNR_RS02915'}
# {'locus_tag': 'XNR_RS02920'}
# {'locus_tag': 'XNR_RS02925'}
# {'locus_tag': 'XNR_RS02930'}
# {'locus_tag': 'XNR_RS02935'}
# {'locus_tag': 'XNR_RS02940'}
# {'locus_tag': 'XNR_RS02945'}
# {'locus_tag': 'XNR_RS02950'}
# {'locus_tag': 'XNR_RS02955'}
# {'locus_tag': 'XNR_RS02960'}
# {'locus_tag': 'XNR_RS02965'}
# {'locus_tag': 'XNR_RS02970'}
# {'locus_tag': 'XNR_RS04785'}
# {'locus_tag': 'XNR_RS04790'}
# {'locus_tag': 'XNR_RS04795'}
# {'locus_tag': 'XNR_RS04800'}
# {'locus_tag': 'XNR_RS04805'}
# {'locus_tag': 'XNR_RS04810'}
# {'locus_tag': 'XNR_RS04815'}
# {'locus_tag': 'XNR_RS04820'}
# {'locus_tag': 'XNR_RS04825'}
# {'locus_tag': 'XNR_RS04830'}
# {'locus_tag': 'XNR_RS04835'}
# {'locus_tag': 'XNR_RS04840'}
# {'locus_tag': 'XNR_RS04845'}
# {'locus_tag': 'XNR_RS04850'}
# {'locus_tag': 'XNR_RS04855'}
# {'locus_tag': 'XNR_RS04860'}
# {'locus_tag': 'XNR_RS04865'}
# {'locus_tag': 'XNR_RS04870'}
# {'locus_tag': 'XNR_RS04875'}
# {'locus_tag': 'XNR_RS04880'}
# {'locus_tag': 'XNR_RS04885'}
# {'locus_tag': 'XNR_RS04890'}
# {'locus_tag': 'XNR_RS04895'}
# {'locus_tag': 'XNR_RS04900'}
# {'locus_tag': 'XNR_RS04905'}
# {'locus_tag': 'XNR_RS04910'}
# {'locus_tag': 'XNR_RS04915'}
# {'locus_tag': 'XNR_RS04920'}
# {'locus_tag': 'XNR_RS04925'}
# {'locus_tag': 'XNR_RS04930'}
# {'locus_tag': 'XNR_RS04935'}
# {'locus_tag': 'XNR_RS04940'}
# {'locus_tag': 'XNR_RS04945'}
# {'locus_tag': 'XNR_RS04950'}
# {'locus_tag': 'XNR_RS04955'}
# {'locus_tag': 'XNR_RS04960'}
# {'locus_tag': 'XNR_RS04965'}
# {'locus_tag': 'XNR_RS05250'}
# {'locus_tag': 'XNR_RS05255'}
# {'locus_tag': 'XNR_RS05260'}
# {'locus_tag': 'XNR_RS05265'}
# {'locus_tag': 'XNR_RS05270'}
# {'locus_tag': 'XNR_RS05275'}
# {'locus_tag': 'XNR_RS05280'}
# {'locus_tag': 'XNR_RS05285'}
# {'locus_tag': 'XNR_RS05290'}
# {'locus_tag': 'XNR_RS06370'}
# {'locus_tag': 'XNR_RS06375'}
# {'locus_tag': 'XNR_RS06380'}
# {'locus_tag': 'XNR_RS06385'}
# {'locus_tag': 'XNR_RS06390'}
# {'locus_tag': 'XNR_RS06395'}
# {'locus_tag': 'XNR_RS06400'}
# {'locus_tag': 'XNR_RS06405'}
# {'locus_tag': 'XNR_RS06410'}
# {'locus_tag': 'XNR_RS06415'}
# {'locus_tag': 'XNR_RS06420'}
# {'locus_tag': 'XNR_RS06425'}
# {'locus_tag': 'XNR_RS30445'}
# {'locus_tag': 'XNR_RS06430'}
# {'locus_tag': 'XNR_RS06435'}
# {'locus_tag': 'XNR_RS06440'}
# {'locus_tag': 'XNR_RS06445'}
# {'locus_tag': 'XNR_RS06450'}
# {'locus_tag': 'XNR_RS06455'}
# {'locus_tag': 'XNR_RS06460'}
# {'locus_tag': 'XNR_RS07815'}
# {'locus_tag': 'XNR_RS07820'}
# {'locus_tag': 'XNR_RS07825'}
# {'locus_tag': 'XNR_RS07830'}
# {'locus_tag': 'XNR_RS07835'}
# {'locus_tag': 'XNR_RS07840'}
# {'locus_tag': 'XNR_RS07845'}
# {'locus_tag': 'XNR_RS07850'}
# {'locus_tag': 'XNR_RS07855'}
# {'locus_tag': 'XNR_RS07860'}
# {'locus_tag': 'XNR_RS07865'}
# {'locus_tag': 'XNR_RS07870'}
# {'locus_tag': 'XNR_RS07875'}
# {'locus_tag': 'XNR_RS07880'}
# {'locus_tag': 'XNR_RS07885'}
# {'locus_tag': 'XNR_RS07890'}
# {'locus_tag': 'XNR_RS07895'}
# {'locus_tag': 'XNR_RS07900'}
# {'locus_tag': 'XNR_RS29710'}
# {'locus_tag': 'XNR_RS10025'}
# {'locus_tag': 'XNR_RS10030'}
# {'locus_tag': 'XNR_RS10035'}
# {'locus_tag': 'XNR_RS10040'}
# {'locus_tag': 'XNR_RS10045'}
# {'locus_tag': 'XNR_RS10050'}
# {'locus_tag': 'XNR_RS10055'}
# {'locus_tag': 'XNR_RS10060'}
# {'locus_tag': 'XNR_RS10065'}
# {'locus_tag': 'XNR_RS10070'}
# {'locus_tag': 'XNR_RS10075'}
# {'locus_tag': 'XNR_RS10080'}
# {'locus_tag': 'XNR_RS10085'}
# {'locus_tag': 'XNR_RS10090'}
# {'locus_tag': 'XNR_RS10095'}
# {'locus_tag': 'XNR_RS10100'}
# {'locus_tag': 'XNR_RS10105'}
# {'locus_tag': 'XNR_RS10110'}
# {'locus_tag': 'XNR_RS10115'}
# {'locus_tag': 'XNR_RS10120'}
# {'locus_tag': 'XNR_RS10125'}
# {'locus_tag': 'XNR_RS10130'}
# {'locus_tag': 'XNR_RS10135'}
# {'locus_tag': 'XNR_RS10140'}
# {'locus_tag': 'XNR_RS10145'}
# {'locus_tag': 'XNR_RS10150'}
# {'locus_tag': 'XNR_RS10865'}
# {'locus_tag': 'XNR_RS10870'}
# {'locus_tag': 'XNR_RS31180'}
# {'locus_tag': 'XNR_RS31185'}
# {'locus_tag': 'XNR_RS10895'}
# {'locus_tag': 'XNR_RS30300'}
# {'locus_tag': 'XNR_RS10905'}
# {'locus_tag': 'XNR_RS29755'}
# {'locus_tag': 'XNR_RS30305'}
# {'locus_tag': 'XNR_RS29770'}
# {'locus_tag': 'XNR_RS10925'}
# {'locus_tag': 'XNR_RS10930'}
# {'locus_tag': 'XNR_RS11535'}
# {'locus_tag': 'XNR_RS11540'}
# {'locus_tag': 'XNR_RS11545'}
# {'locus_tag': 'XNR_RS31190'}
# {'locus_tag': 'XNR_RS11555'}
# {'locus_tag': 'XNR_RS11560'}
# {'locus_tag': 'XNR_RS11565'}
# {'locus_tag': 'XNR_RS11570'}
# {'locus_tag': 'XNR_RS11575'}
# {'locus_tag': 'XNR_RS11580'}
# {'locus_tag': 'XNR_RS11585'}
# {'locus_tag': 'XNR_RS11590'}
# {'locus_tag': 'XNR_RS11595'}
# {'locus_tag': 'XNR_RS11600'}
# {'locus_tag': 'XNR_RS11605'}
# {'locus_tag': 'XNR_RS11610'}
# {'locus_tag': 'XNR_RS11615'}
# {'locus_tag': 'XNR_RS15505'}
# {'locus_tag': 'XNR_RS15510'}
# {'locus_tag': 'XNR_RS15515'}
# {'locus_tag': 'XNR_RS15520'}
# {'locus_tag': 'XNR_RS15530'}
# {'locus_tag': 'XNR_RS15535'}
# {'locus_tag': 'XNR_RS15540'}
# {'locus_tag': 'XNR_RS15545'}
# {'locus_tag': 'XNR_RS15550'}
# {'locus_tag': 'XNR_RS15555'}
# {'locus_tag': 'XNR_RS15560'}
# {'locus_tag': 'XNR_RS15565'}
# {'locus_tag': 'XNR_RS15570'}
# {'locus_tag': 'XNR_RS15575'}
# {'locus_tag': 'XNR_RS15580'}
# {'locus_tag': 'XNR_RS15585'}
# {'locus_tag': 'XNR_RS15590'}
# {'locus_tag': 'XNR_RS15595'}
# {'locus_tag': 'XNR_RS15600'}
# {'locus_tag': 'XNR_RS15605'}
# {'locus_tag': 'XNR_RS15610'}
# {'locus_tag': 'XNR_RS15615'}
# {'locus_tag': 'XNR_RS15620'}
# {'locus_tag': 'XNR_RS15625'}
# {'locus_tag': 'XNR_RS15630'}
# {'locus_tag': 'XNR_RS15635'}
# {'locus_tag': 'XNR_RS15640'}
# {'locus_tag': 'XNR_RS15645'}
# {'locus_tag': 'XNR_RS29930'}
# {'locus_tag': 'XNR_RS17000'}
# {'locus_tag': 'XNR_RS17005'}
# {'locus_tag': 'XNR_RS17010'}
# {'locus_tag': 'XNR_RS17015'}
# {'locus_tag': 'XNR_RS17020'}
# {'locus_tag': 'XNR_RS17025'}
# {'locus_tag': 'XNR_RS17030'}
# {'locus_tag': 'XNR_RS17035'}
# {'locus_tag': 'XNR_RS17040'}
# {'locus_tag': 'XNR_RS17045'}
# {'locus_tag': 'XNR_RS17050'}
# {'locus_tag': 'XNR_RS17055'}
# {'locus_tag': 'XNR_RS17060'}
# {'locus_tag': 'XNR_RS17065'}
# {'locus_tag': 'XNR_RS29975'}
# {'locus_tag': 'XNR_RS17075'}
# {'locus_tag': 'XNR_RS17080'}
# {'locus_tag': 'XNR_RS17085'}
# {'locus_tag': 'XNR_RS17090'}
# {'locus_tag': 'XNR_RS17095'}
# {'locus_tag': 'XNR_RS17100'}
# {'locus_tag': 'XNR_RS17105'}
# {'locus_tag': 'XNR_RS17110'}
# {'locus_tag': 'XNR_RS17115'}
# {'locus_tag': 'XNR_RS17120'}
# {'locus_tag': 'XNR_RS17125'}
# {'locus_tag': 'XNR_RS17130'}
# {'locus_tag': 'XNR_RS17135'}
# {'locus_tag': 'XNR_RS17140'}
# {'locus_tag': 'XNR_RS17145'}
# {'locus_tag': 'XNR_RS17150'}
# {'locus_tag': 'XNR_RS17155'}
# {'locus_tag': 'XNR_RS17160'}
# {'locus_tag': 'XNR_RS30855'}
# {'locus_tag': 'XNR_RS17165'}
# {'locus_tag': 'XNR_RS17170'}
# {'locus_tag': 'XNR_RS17175'}
# {'locus_tag': 'XNR_RS17180'}
# {'locus_tag': 'XNR_RS17185'}
# {'locus_tag': 'XNR_RS17190'}
# {'locus_tag': 'XNR_RS17195'}
# {'locus_tag': 'XNR_RS17200'}
# {'locus_tag': 'XNR_RS17205'}
# {'locus_tag': 'XNR_RS17210'}
# {'locus_tag': 'XNR_RS19470'}
# {'locus_tag': 'XNR_RS19475'}
# {'locus_tag': 'XNR_RS19480'}
# {'locus_tag': 'XNR_RS19485'}
# {'locus_tag': 'XNR_RS19490'}
# {'locus_tag': 'XNR_RS19495'}
# {'locus_tag': 'XNR_RS19500'}
# {'locus_tag': 'XNR_RS19505'}
# {'locus_tag': 'XNR_RS19510'}
# {'locus_tag': 'XNR_RS19515'}
# {'locus_tag': 'XNR_RS19520'}
# {'locus_tag': 'XNR_RS19525'}
# {'locus_tag': 'XNR_RS19530'}
# {'locus_tag': 'XNR_RS19535'}
# {'locus_tag': 'XNR_RS19540'}
# {'locus_tag': 'XNR_RS19545'}
# {'locus_tag': 'XNR_RS19550'}
# {'locus_tag': 'XNR_RS19555'}
# {'locus_tag': 'XNR_RS19560'}
# {'locus_tag': 'XNR_RS19565'}
# {'locus_tag': 'XNR_RS19570'}
# {'locus_tag': 'XNR_RS19575'}
# {'locus_tag': 'XNR_RS19580'}
# {'locus_tag': 'XNR_RS19585'}
# {'locus_tag': 'XNR_RS19590'}
# {'locus_tag': 'XNR_RS19595'}
# {'locus_tag': 'XNR_RS19600'}
# {'locus_tag': 'XNR_RS19605'}
# {'locus_tag': 'XNR_RS19610'}
# {'locus_tag': 'XNR_RS19615'}
# {'locus_tag': 'XNR_RS19620'}
# {'locus_tag': 'XNR_RS19625'}
# {'locus_tag': 'XNR_RS19630'}
# {'locus_tag': 'XNR_RS19635'}
# {'locus_tag': 'XNR_RS31605'}
# {'locus_tag': 'XNR_RS19645'}
# {'locus_tag': 'XNR_RS19650'}
# {'locus_tag': 'XNR_RS19655'}
# {'locus_tag': 'XNR_RS20695'}
# {'locus_tag': 'XNR_RS20700'}
# {'locus_tag': 'XNR_RS20705'}
# {'locus_tag': 'XNR_RS20710'}
# {'locus_tag': 'XNR_RS20715'}
# {'locus_tag': 'XNR_RS20720'}
# {'locus_tag': 'XNR_RS20725'}
# {'locus_tag': 'XNR_RS20730'}
# {'locus_tag': 'XNR_RS20735'}
# {'locus_tag': 'XNR_RS20740'}
# {'locus_tag': 'XNR_RS24540'}
# {'locus_tag': 'XNR_RS24545'}
# {'locus_tag': 'XNR_RS24550'}
# {'locus_tag': 'XNR_RS24555'}
# {'locus_tag': 'XNR_RS24560'}
# {'locus_tag': 'XNR_RS24565'}
# {'locus_tag': 'XNR_RS24570'}
# {'locus_tag': 'XNR_RS24575'}
# {'locus_tag': 'XNR_RS24580'}
# {'locus_tag': 'XNR_RS24585'}
# {'locus_tag': 'XNR_RS27845'}
# {'locus_tag': 'XNR_RS27850'}
# {'locus_tag': 'XNR_RS27855'}
# {'locus_tag': 'XNR_RS27860'}
# {'locus_tag': 'XNR_RS27865'}
# {'locus_tag': 'XNR_RS27870'}
# {'locus_tag': 'XNR_RS27875'}
# {'locus_tag': 'XNR_RS27880'}
# {'locus_tag': 'XNR_RS27885'}
# {'locus_tag': 'XNR_RS27890'}
# {'locus_tag': 'XNR_RS27895'}
# {'locus_tag': 'XNR_RS27900'}
# {'locus_tag': 'XNR_RS27905'}
# {'locus_tag': 'XNR_RS27910'}
# {'locus_tag': 'XNR_RS27915'}
# {'locus_tag': 'XNR_RS27920'}
# {'locus_tag': 'XNR_RS27925'}
# {'locus_tag': 'XNR_RS27930'}
# {'locus_tag': 'XNR_RS27935'}
# {'locus_tag': 'XNR_RS27940'}
# {'locus_tag': 'XNR_RS27945'}
# {'locus_tag': 'XNR_RS27950'}
# {'locus_tag': 'XNR_RS27955'}
# {'locus_tag': 'XNR_RS27960'}
# {'locus_tag': 'XNR_RS27965'}
# {'locus_tag': 'XNR_RS27970'}
# {'locus_tag': 'XNR_RS27975'}
# {'locus_tag': 'XNR_RS30700'}
# {'locus_tag': 'XNR_RS27980'}
# {'locus_tag': 'XNR_RS27985'}
# {'locus_tag': 'XNR_RS27990'}
# {'locus_tag': 'XNR_RS27995'}
# {'locus_tag': 'XNR_RS28000'}
# {'locus_tag': 'XNR_RS28005'}
# {'locus_tag': 'XNR_RS28010'}
# {'locus_tag': 'XNR_RS28015'}
# {'locus_tag': 'XNR_RS28020'}
# {'locus_tag': 'XNR_RS28025'}
# {'locus_tag': 'XNR_RS28030'}
# {'locus_tag': 'XNR_RS28035'}
# {'locus_tag': 'XNR_RS28140'}
# {'locus_tag': 'XNR_RS28145'}
# {'locus_tag': 'XNR_RS28150'}
# {'locus_tag': 'XNR_RS28155'}
# {'locus_tag': 'XNR_RS28160'}
# {'locus_tag': 'XNR_RS28165'}
# {'locus_tag': 'XNR_RS28170'}
# {'locus_tag': 'XNR_RS28175'}
# {'locus_tag': 'XNR_RS28180'}
# {'locus_tag': 'XNR_RS28185'}
# {'locus_tag': 'XNR_RS28190'}
# {'locus_tag': 'XNR_RS28195'}
# {'locus_tag': 'XNR_RS28200'}
# {'locus_tag': 'XNR_RS28205'}
# {'locus_tag': 'XNR_RS30185'}
# {'locus_tag': 'XNR_RS28215'}
# {'locus_tag': 'XNR_RS30190'}
# {'locus_tag': 'XNR_RS28225'}
# {'locus_tag': 'XNR_RS28230'}
# {'locus_tag': 'XNR_RS28235'}
# {'locus_tag': 'XNR_RS28240'}
# {'locus_tag': 'XNR_RS28245'}
# {'locus_tag': 'XNR_RS28250'}
# {'locus_tag': 'XNR_RS28255'}
# {'locus_tag': 'XNR_RS28260'}
# {'locus_tag': 'XNR_RS28265'}
# {'locus_tag': 'XNR_RS28270'}
# {'locus_tag': 'XNR_RS28275'}
# {'locus_tag': 'XNR_RS30195'}
# {'locus_tag': 'XNR_RS28280'}
# {'locus_tag': 'XNR_RS28285'}
# {'locus_tag': 'XNR_RS28290'}
# {'locus_tag': 'XNR_RS28610'}
# {'locus_tag': 'XNR_RS28615'}
# {'locus_tag': 'XNR_RS31665'}
# {'locus_tag': 'XNR_RS28620'}
# {'locus_tag': 'XNR_RS28625'}
# {'locus_tag': 'XNR_RS28630'}
# {'locus_tag': 'XNR_RS28635'}
# {'locus_tag': 'XNR_RS28640'}
# {'locus_tag': 'XNR_RS28645'}
# {'locus_tag': 'XNR_RS28690'}
# {'locus_tag': 'XNR_RS28695'}
# {'locus_tag': 'XNR_RS28700'}
# {'locus_tag': 'XNR_RS28705'}
# {'locus_tag': 'XNR_RS28710'}
# {'locus_tag': 'XNR_RS28715'}
# {'locus_tag': 'XNR_RS28720'}
# {'locus_tag': 'XNR_RS28725'}
# {'locus_tag': 'XNR_RS28730'}
# {'locus_tag': 'XNR_RS28735'}
# {'locus_tag': 'XNR_RS28740'}
# {'locus_tag': 'XNR_RS28745'}
# {'locus_tag': 'XNR_RS28750'}
# {'locus_tag': 'XNR_RS28755'}
# {'locus_tag': 'XNR_RS28760'}
# {'locus_tag': 'XNR_RS28765'}
# {'locus_tag': 'XNR_RS28770'}
# {'locus_tag': 'XNR_RS28775'}
# {'locus_tag': 'XNR_RS28780'}
# {'locus_tag': 'XNR_RS28785'}
# {'locus_tag': 'XNR_RS28790'}
# {'locus_tag': 'XNR_RS28795'}
# {'locus_tag': 'XNR_RS28800'}
# {'locus_tag': 'XNR_RS28805'}
# {'locus_tag': 'XNR_RS28810'}
# {'locus_tag': 'XNR_RS28815'}
# {'locus_tag': 'XNR_RS28820'}
# {'locus_tag': 'XNR_RS28825'}
# {'locus_tag': 'XNR_RS28830'}
# {'locus_tag': 'XNR_RS28835'}
# {'locus_tag': 'XNR_RS28840'}
# {'locus_tag': 'XNR_RS28845'}
# {'locus_tag': 'XNR_RS28850'}
# {'locus_tag': 'XNR_RS28855'}
# {'locus_tag': 'XNR_RS28860'}
# {'locus_tag': 'XNR_RS28865'}
# {'locus_tag': 'XNR_RS28870'}
# {'locus_tag': 'XNR_RS28875'}
# {'locus_tag': 'XNR_RS28880'}
# {'locus_tag': 'XNR_RS28885'}
# {'locus_tag': 'XNR_RS31430'}
# {'locus_tag': 'XNR_RS28920'}
# {'locus_tag': 'XNR_RS28925'}
# {'locus_tag': 'XNR_RS28930'}
# {'locus_tag': 'XNR_RS28935'}
# {'locus_tag': 'XNR_RS28940'}
# {'locus_tag': 'XNR_RS28945'}
# {'locus_tag': 'XNR_RS28950'}
# {'locus_tag': 'XNR_RS28955'}
# {'locus_tag': 'XNR_RS28960'}
# {'locus_tag': 'XNR_RS28965'}
# {'locus_tag': 'XNR_RS28970'}
# {'locus_tag': 'XNR_RS28975'}
# {'locus_tag': 'XNR_RS28980'}
# {'locus_tag': 'XNR_RS28985'}
# {'locus_tag': 'XNR_RS28990'}
# {'locus_tag': 'XNR_RS28995'}
# {'locus_tag': 'XNR_RS29000'}
# {'locus_tag': 'XNR_RS29005'}
# {'locus_tag': 'XNR_RS29010'}
# {'locus_tag': 'XNR_RS29015'}
# {'locus_tag': 'XNR_RS29020'}
# {'locus_tag': 'XNR_RS29025'}
# {'locus_tag': 'XNR_RS29030'}
# {'locus_tag': 'XNR_RS31435'}
# {'locus_tag': 'XNR_RS29040'}
# {'locus_tag': 'XNR_RS29045'}
# {'locus_tag': 'XNR_RS29050'}
# {'locus_tag': 'XNR_RS29055'}
# {'locus_tag': 'XNR_RS29060'}
# {'locus_tag': 'XNR_RS29065'}
# {'locus_tag': 'XNR_RS29070'}
# {'locus_tag': 'XNR_RS29075'}
# {'locus_tag': 'XNR_RS29080'}
# {'locus_tag': 'XNR_RS29085'}
# {'locus_tag': 'XNR_RS31670'}
# {'locus_tag': 'XNR_RS29095'}
# {'locus_tag': 'XNR_RS29100'}
# {'locus_tag': 'XNR_RS29105'}
# {'locus_tag': 'XNR_RS29110'}
# {'locus_tag': 'XNR_RS29115'}
# {'locus_tag': 'XNR_RS29120'}
# {'locus_tag': 'XNR_RS29125'}
# {'locus_tag': 'XNR_RS29130'}
# {'locus_tag': 'XNR_RS29135'}
# {'locus_tag': 'XNR_RS29140'}
# {'locus_tag': 'XNR_RS30540'}
# {'locus_tag': 'XNR_RS30545'}
# {'locus_tag': 'XNR_RS29155'}
# {'locus_tag': 'XNR_RS29160'}
# {'locus_tag': 'XNR_RS29165'}
# {'locus_tag': 'XNR_RS29170'}
# {'locus_tag': 'XNR_RS29175'}
# {'locus_tag': 'XNR_RS29180'}
# {'locus_tag': 'XNR_RS29185'}
# {'locus_tag': 'XNR_RS29190'}
# {'locus_tag': 'XNR_RS29195'}
# {'locus_tag': 'XNR_RS29200'}
# {'locus_tag': 'XNR_RS29205'}
# {'locus_tag': 'XNR_RS29210'}
# {'locus_tag': 'XNR_RS29215'}
# {'locus_tag': 'XNR_RS29220'}
# {'locus_tag': 'XNR_RS29225'}
# {'locus_tag': 'XNR_RS29230'}
# {'locus_tag': 'allorf_6768184_6768369'}
# {'locus_tag': 'XNR_RS29235'}
# {'locus_tag': 'XNR_RS29240'}
# {'locus_tag': 'XNR_RS29245'}
# {'locus_tag': 'XNR_RS29250'}
# {'locus_tag': 'XNR_RS29255'}
# {'locus_tag': 'XNR_RS29260'}
# {'locus_tag': 'XNR_RS30980'}
# {'locus_tag': 'XNR_RS29265'}
# {'locus_tag': 'XNR_RS29270'}
# {'locus_tag': 'XNR_RS29275'}
# {'locus_tag': 'XNR_RS29280'}
# {'locus_tag': 'XNR_RS29285'}
# {'locus_tag': 'XNR_RS29290'}
# {'locus_tag': 'XNR_RS29295'}
# {'locus_tag': 'XNR_RS29300'}
# {'locus_tag': 'XNR_RS29305'}
# {'locus_tag': 'XNR_RS29310'}
# {'locus_tag': 'XNR_RS29315'}
# {'locus_tag': 'XNR_RS29320'}
# {'locus_tag': 'XNR_RS30550'}
# {'locus_tag': 'XNR_RS29330'}
# {'locus_tag': 'XNR_RS31675'}
# {'locus_tag': 'XNR_RS29340'}
# {'locus_tag': 'XNR_RS31680'}
# {'locus_tag': 'XNR_RS29350'}
# {'locus_tag': 'XNR_RS29355'}
# {'locus_tag': 'XNR_RS29360'}
# {'locus_tag': 'XNR_RS29365'}
# {'locus_tag': 'XNR_RS29370'}
# {'locus_tag': 'XNR_RS29375'}
# {'locus_tag': 'XNR_RS29380'}
# {'locus_tag': 'XNR_RS29385'}
# {'locus_tag': 'XNR_RS29390'}
# {'locus_tag': 'XNR_RS29395'}
# {'locus_tag': 'XNR_RS29400'}
# {'locus_tag': 'XNR_RS29405'}
# {'locus_tag': 'XNR_RS29410'}
# {'locus_tag': 'XNR_RS29415'}
# {'locus_tag': 'XNR_RS29420'}
# {'locus_tag': 'XNR_RS29425'}
# {'locus_tag': 'XNR_RS29430'}

# %%
# Load the CSV files into pandas DataFrames
df_bgc = pd.read_csv("../../data/external/S_albus_antismash/bgc_gene_list.csv")
df_imodulon = pd.read_csv("../../data/processed/genes_with_imodulon.csv")

# Merge the DataFrames
df_merged = pd.merge(df_bgc, df_imodulon, on="gene_id", how="outer")


print(df_merged)

# Write the merged DataFrame to a CSV file
file_path = os.path.join(data_dir, "merged_gene_list.csv")
df_merged.to_csv(file_path, index=False)
# Out:
#           gene_id  BGC     Imodulon
# 0     XNR_RS00010  1.0   DNA Damage
# 1     XNR_RS00015  1.0          NaN
# 2     XNR_RS00020  1.0          NaN
# 3     XNR_RS00025  1.0          NaN
# 4     XNR_RS00030  1.0   DNA Damage
# ...           ...  ...          ...
# 2985  XNR_RS27840  NaN        UC-14
# 2986  XNR_RS28670  NaN        UC-14
# 2987  XNR_RS28680  NaN        UC-14
# 2988  XNR_RS12320  NaN  hrt Complex
# 2989  XNR_RS12325  NaN  hrt Complex
#
# [2990 rows x 3 columns]

# %%
#Group by BGC and imodulon
grouped = df_merged.groupby(['BGC', 'Imodulon'])

#calculate the total number of genes per imodulon
total_genes = grouped['gene_id'].count().reset_index().rename(columns={'gene_id':'total_bgc_genes'})

# Grouping by Imodulon and counting the non-null gene_id values in each group
gene_counts = df_merged.groupby('Imodulon')['gene_id'].count()

# Joining the gene counts with the total_genes DataFrame based on Imodulon
result = pd.merge(total_genes, gene_counts, left_on='Imodulon', right_index=True, how='left')

# Renaming the columns for clarity
result.rename(columns={'gene_id': 'genes_in_imodulon'}, inplace=True)

# Calculating the percentage of genes in each BGC that are in each imodulon
result['percentage'] = result['total_bgc_genes'] / result['genes_in_imodulon'] * 100

# Printing the result DataFrame
print(result)

# Write the result DataFrame to a CSV file
file_path = os.path.join(data_dir, "result.csv")
result.to_csv(file_path, index=False)
# Out:
#       BGC              Imodulon  total_bgc_genes  genes_in_imodulon  \
# 0     1.0  BGC-1 and 23 Related               11                 17
# 1     1.0           BGC-General                7                197
# 2     1.0      Del14, Unknown-5                1                187
# 3     1.0              Fructose                5                  5
# 4     1.0           Nuo Complex                2                183
# ..    ...                   ...              ...                ...
# 251  23.0            Unknown-15                9                241
# 252  23.0            Unknown-16                4                514
# 253  23.0            Unknown-17                1                411
# 254  23.0             Unknown-2                1                248
# 255  23.0             Unknown-9                5                431
#
#      percentage
# 0     64.705882
# 1      3.553299
# 2      0.534759
# 3    100.000000
# 4      1.092896
# ..          ...
# 251    3.734440
# 252    0.778210
# 253    0.243309
# 254    0.403226
# 255    1.160093
#
# [256 rows x 5 columns]
